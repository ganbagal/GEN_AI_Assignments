# %% [markdown]
# <a href="https://colab.research.google.com/github/ganbagal/GEN_AI_Assignments/blob/main/GEN_AI_Assignments_Problem_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a Python program to draw (visualize) the architecture of a **Neural Network** used to classify fraudulent and non-fraudulent credit card transactions.
#
# Assume the fraud detection dataset contains the following input features:
#
# 1. Transaction Amount
#
# 2. Transaction Time
#
# 3. Merchant Category
#
# 4. Customer Age
#
# 5. Account Balance
#
# 6. Number Of Transactions Today
#
# 7. Fraud (0 = Genuine, 1 = Fraud)

# %%
# Import required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils  import plot_model

# %%
# Create Sample Dataset

data = {
        "TransactionAmount":[70000,1200,90000,2000,50000,1500],
        "TransactionTime":[2,16,1,10,23,14],
        "MerchantCategory":["Electronics","Grocery","Luxury","Grocery","Luxury","Grocery"],
        "CustomerAge":[50,28,60,35,45,30],
        "AccountBalance":[2000000,30000,3000000,50000,1000000,40000],
        "NumOfTransToday":[15,1,20,2,10,1],
        "Fraud":[0,1,0,1,0,1]
}
df = pd.DataFrame(data)

# %%
encoder = LabelEncoder()
df["MerchantCategory"] = encoder.fit_transform(df["MerchantCategory"])

X = df.drop("Fraud", axis=1)
y = df["Fraud"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Build Nural Network

model = Sequential()

model.add(Dense(16,activation='relu',input_shape=(X_train.shape[1],)))

model.add(Dense(8,activation='relu'))

model.add(Dense(1,activation='sigmoid'))

# %%
# Compile Model :

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
# Train the model

history = model.fit(X_train,y_train,epochs=50,batch_size=2,validation_split=0.2,verbose=1)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - accuracy: 0.6111 - loss: 0.5579 - val_accuracy: 0.0000e+00 - val_loss: 0.7576
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6111 - loss: 0.5069 - val_accuracy: 0.0000e+00 - val_loss: 0.7472
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6111 - loss: 0.5275 - val_accuracy: 0.0000e+00 - val_loss: 0.7377
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6111 - loss: 0.4785 - val_accuracy: 0.0000e+00 - val_loss: 0.7283
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7778 - loss: 0.3908 - val_accuracy: 0.0000e+00 - val_loss: 0.7197
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7778 - loss: 0.3783 - val_accuracy: 0.0000e+00 - val_loss: 0.7101
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6111 - loss: 0.4764 - val_accuracy: 0.0000e+00 - val_loss: 0.6997
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6111 - loss: 0.4644 - val_accuracy: 1.0000 - val_loss: 0.6899
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7778 - loss: 0.3456 - val_accuracy: 1.0000 - val_loss: 0.6807
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6111 - loss: 0.4082 - val_accuracy: 1.0000 - val_loss: 0.6709
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6111 - loss: 0.4316 - val_accuracy: 1.0000 - val_loss: 0.6616
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7778 - loss: 0.3166 - val_accuracy: 1.0000 - val_loss: 0.6529
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6111 - loss: 0.3783 - val_accuracy: 1.0000 - val_loss: 0.6434
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6111 - loss: 0.3688 - val_accuracy: 1.0000 - val_loss: 0.6345
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.3598 - val_accuracy: 1.0000 - val_loss: 0.6261
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.2827 - val_accuracy: 1.0000 - val_loss: 0.6181
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.3746 - val_accuracy: 1.0000 - val_loss: 0.6095
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.3664 - val_accuracy: 1.0000 - val_loss: 0.6013
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.2611 - val_accuracy: 1.0000 - val_loss: 0.5937
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.2542 - val_accuracy: 1.0000 - val_loss: 0.5854
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.3428 - val_accuracy: 1.0000 - val_loss: 0.5767
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.3349 - val_accuracy: 1.0000 - val_loss: 0.5686
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.3000 - val_accuracy: 1.0000 - val_loss: 0.5609
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.2305 - val_accuracy: 1.0000 - val_loss: 0.5535
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.2877 - val_accuracy: 1.0000 - val_loss: 0.5454
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.2815 - val_accuracy: 1.0000 - val_loss: 0.5378
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.2755 - val_accuracy: 1.0000 - val_loss: 0.5305
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.2952 - val_accuracy: 1.0000 - val_loss: 0.5235
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.2889 - val_accuracy: 1.0000 - val_loss: 0.5168
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.2831 - val_accuracy: 1.0000 - val_loss: 0.5103
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.1949 - val_accuracy: 1.0000 - val_loss: 0.5045
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.2492 - val_accuracy: 1.0000 - val_loss: 0.4985
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.1861 - val_accuracy: 1.0000 - val_loss: 0.4927
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.2392 - val_accuracy: 1.0000 - val_loss: 0.4862
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.1776 - val_accuracy: 1.0000 - val_loss: 0.4800
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.2292 - val_accuracy: 1.0000 - val_loss: 0.4733
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.2448 - val_accuracy: 1.0000 - val_loss: 0.4669
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.2196 - val_accuracy: 1.0000 - val_loss: 0.4609
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.2151 - val_accuracy: 1.0000 - val_loss: 0.4553
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.2299 - val_accuracy: 1.0000 - val_loss: 0.4499
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.2252 - val_accuracy: 1.0000 - val_loss: 0.4447
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.2208 - val_accuracy: 1.0000 - val_loss: 0.4395
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.1987 - val_accuracy: 1.0000 - val_loss: 0.4344
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.2124 - val_accuracy: 1.0000 - val_loss: 0.4294
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.1420 - val_accuracy: 1.0000 - val_loss: 0.4245
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.2044 - val_accuracy: 1.0000 - val_loss: 0.4188
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.1361 - val_accuracy: 1.0000 - val_loss: 0.4134
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.1333 - val_accuracy: 1.0000 - val_loss: 0.4077
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.1310 - val_accuracy: 1.0000 - val_loss: 0.4021
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.1287 - val_accuracy: 1.0000 - val_loss: 0.3965

# %%
# Predictions :

y_pred = (model.predict(X_test) > 0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step

# %%
# Evaluation Metrics

print("Confusion Matrix:")
print(confusion_matrix(y_test,y_pred))

print("\nClassification Report:")
print(classification_report(y_test,y_pred))
# Out:
# Confusion Matrix:
# [[1 0]
#  [0 1]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %%
# Texual Architecture View

model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 16)             │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 773 (3.02 KB)
#  Trainable params: 257 (1.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 516 (2.02 KB)

# %%
# Architecture Diagram

plot_model(model,show_shapes=True,show_layer_names=True)
